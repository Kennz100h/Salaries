# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Kenneth\Desktop\PYTHON\Salaries.csv")

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
df.tail()
# Out:
#             Id   EmployeeName                    JobTitle  BasePay  \
# 148649  148650  Roy I Tillery                   Custodian      0.0
# 148650  148651   Not provided                Not provided      NaN
# 148651  148652   Not provided                Not provided      NaN
# 148652  148653   Not provided                Not provided      NaN
# 148653  148654      Joe Lopez  Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148649          0.0      0.00       0.0      0.00              0.00  2014
# 148650          NaN       NaN       NaN      0.00              0.00  2014
# 148651          NaN       NaN       NaN      0.00              0.00  2014
# 148652          NaN       NaN       NaN      0.00              0.00  2014
# 148653          0.0   -618.13       0.0   -618.13           -618.13  2014
#
#         Notes         Agency  Status
# 148649    NaN  San Francisco     NaN
# 148650    NaN  San Francisco     NaN
# ...

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448840    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %%
df.sample()
# Out:
#           Id  EmployeeName            JobTitle    BasePay  OvertimePay  \
# 74208  74209  Dawn M Nance  Nurse Practitioner  164108.99     16592.01
#
#        OtherPay  Benefits   TotalPay  TotalPayBenefits  Year  Notes  \
# 74208    490.81  49175.11  181191.81         230366.92  2013    NaN
#
#               Agency  Status
# 74208  San Francisco     NaN

# %%
df.shape
# Out:
# (148654, 13)

# %%
df.shape[1]
# Out:
# 13

# %%
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %%
print("The number of rows in this data is" , df.shape[0] , "rows")
# Out:
# The number of rows in this data is 148654 rows

# %%
print("The number of columns in this data is" , df.shape[1] , "columns")
# Out:
# The number of columns in this data is 13 columns

# %% [markdown]
# ## Numerical and categorical codes

# %%
# Group columns into numerical and categorical
numerical_cols = df.select_dtypes(include=['number']).columns.tolist()
categorical_cols = df.select_dtypes(exclude=['number']).columns.tolist()

# %%
numerical_cols
# Out:
# ['Id',
#  'BasePay',
#  'OvertimePay',
#  'OtherPay',
#  'Benefits',
#  'TotalPay',
#  'TotalPayBenefits',
#  'Year',
#  'Notes',
#  'Status']

# %%
categorical_cols
# Out:
# ['EmployeeName', 'JobTitle', 'Agency']

# %% [markdown]
# ## Code to exclude unique values

# %%
# Exclude specific columns
excluded_cols = ['Order ID', 'Order Date', 'Ship Date', 'Customer ID', 'Customer Name']
# Select categorical columns
categorical_cols = df.select_dtypes(exclude=['number']).columns.tolist()
# Remove excluded columns
filtered_categorical_cols = [col for col in categorical_cols if col not in excluded_cols]
# Get unique values for each categorical column
unique_values = {col: df[col].unique().tolist() for col in filtered_categorical_cols}
# Print the unique values
for col, values in unique_values.items():
    print(f"{col}: {values[:10]}")  # Limiting to first 10 unique values for readability
# Out:
# EmployeeName: ['NATHANIEL FORD', 'GARY JIMENEZ', 'ALBERT PARDINI', 'CHRISTOPHER CHONG', 'PATRICK GARDNER', 'DAVID SULLIVAN', 'ALSON LEE', 'DAVID KUSHNER', 'MICHAEL MORRIS', 'JOANNE HAYES-WHITE']
# JobTitle: ['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY', 'CAPTAIN III (POLICE DEPARTMENT)', 'WIRE ROPE CABLE MAINTENANCE MECHANIC', 'DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)', 'ASSISTANT DEPUTY CHIEF II', 'BATTALION CHIEF, (FIRE DEPARTMENT)', 'DEPUTY DIRECTOR OF INVESTMENTS', 'CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)', 'ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)', 'EXECUTIVE CONTRACT EMPLOYEE']
# Agency: ['San Francisco']

# %%
# Remove all null values from the dataset
df = df.dropna()

# Verify if null values are removed
print(df.isnull().sum())
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# Benefits            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Notes               0
# Agency              0
# Status              0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# Benefits            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Notes               0
# Agency              0
# Status              0
# dtype: int64

# %% [markdown]
# ##### 1.Find The Occurence Of the Employee Names(Top5)

# %%
# Count occurrences of each EmployeeName
top_employee_names = df['EmployeeName'].value_counts().nlargest(5)  # Get top 5

# Display the results
print(top_employee_names)
# Out:
# EmployeeName
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: count, dtype: int64

# %%
# Plot a bar chart for the most common employee names
plt.figure(figsize=(8, 5))
plt.bar(top_employee_names.index, top_employee_names.values, color='blue', alpha=0.7)

# Labeling
plt.xlabel("Employee Name")
plt.ylabel("Number of Occurrences")
plt.title("Top 5 Most Common Employee Names")
plt.xticks(rotation=45, ha='right')  # Rotate for readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the bar chart
plt.show()

# %% [markdown]
# ##### 2. Find The Number Of Unique Jobs Titles

# %%
num_unique_jobs = df['JobTitle'].nunique()
print(f"Number of unique job titles: {num_unique_jobs}")
# Out:
# Number of unique job titles: 2159

# %% [markdown]
# ##### 3. Find The Total Number Of Job Titles Contain captain

# %%
tot_num_caps = df['JobTitle'].str.contains('captain', case=False, na=False).sum()
print(f"Total number of job titles contain captain" , tot_num_caps)
# Out:
# Total number of job titles contain captain 552

# %% [markdown]
# ##### 4. Display All the Employee Names from Fire Department

# %%
# Filter rows where 'JobTitle' contains 'FIRE DEPARTMENT' (case-insensitive)
fire_dept_employees = df[df['JobTitle'].str.contains('FIRE DEPARTMENT', case=False, na=False)]

# Display the 'EmployeeName' column
fire_dept_employees['EmployeeName']
# Out:
# 4              PATRICK GARDNER
# 6                    ALSON LEE
# 8               MICHAEL MORRIS
# 9           JOANNE HAYES-WHITE
# 10               ARTHUR KENNEY
#                   ...
# 32623             JAMES BARDEN
# 36162       Joanne Hayes-White
# 72926     Joanne M Hayes-White
# 102303          Robert E Evans
# 110535    Joanne M Hayes-White
# Name: EmployeeName, Length: 226, dtype: object

# %%
# List of keywords associated with Fire Department roles
fire_keywords = ['Firefighter', 'Fire Inspector', 'Fire Marshal', 'Fire Protection Engineer',
                 'Fire Captain', 'Fire Lieutenant', 'Fire Chief', 'Fire Investigator']

# Create a boolean mask for rows where 'JobTitle' contains any of the fire-related keywords
fire_dept_mask = df['JobTitle'].apply(lambda x: any(keyword in str(x) for keyword in fire_keywords))

# Filter the DataFrame using the mask
fire_dept_employees = df[fire_dept_mask]

# Display the 'EmployeeName' column
fire_dept_employees['EmployeeName']
# Out:
# 36163     Frederick Binkley
# 36199        Scott Scholzen
# 36206     Gregory Stangland
# 36221             Alvin Lau
# 36231         Mike Breiling
#                 ...
# 145944    Claudia Valentino
# 145956     Kenneth C Farris
# 147556        Edward A Dunn
# 148021       Kari A Johnson
# 148209         Sheryl K Lee
# Name: EmployeeName, Length: 3289, dtype: object

# %% [markdown]
# ##### 5. Find The Minimum,Maximum and Average BasePay

# %%
# Calculate the minimum, maximum, and average BasePay
min_base_pay = df['BasePay'].min()
max_base_pay = df['BasePay'].max()
avg_base_pay = df['BasePay'].mean()

# Data for plotting
categories = ['Minimum BasePay', 'Average BasePay', 'Maximum BasePay']
values = [min_base_pay, avg_base_pay, max_base_pay]

# Create the bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(categories, values, color=['blue', 'green', 'red'])

# Add value labels on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, round(yval, 2), ha='center', va='bottom')

# Add titles and labels
plt.title('Minimum, Average, and Maximum BasePay')
plt.xlabel('Category')
plt.ylabel('BasePay Amount')
plt.ylim(0, max_base_pay + 10000)  # Adjust the y-axis limit for better visualization

# Show the plot
plt.show()

# %%
df['BasePay'].describe()
# Out:
# count    148045.000000
# mean      66325.448840
# std       42764.635495
# min        -166.010000
# 25%       33588.200000
# 50%       65007.450000
# 75%       94691.050000
# max      319275.010000
# Name: BasePay, dtype: float64

# %% [markdown]
# ##### 6. Replace 'Not provided' in EmployeeName Column to Nan

# %%
# Define the list of strings that represent missing values
missing_values = ['not provided', 'n/a', '', '-']

# Convert all entries in 'EmployeeName' to lowercase for case-insensitive comparison
df['EmployeeName'] = df['EmployeeName'].astype(str).str.lower()

# Replace specified missing value indicators with NaN
df['EmployeeName'].replace(missing_values, np.nan, inplace=True)

# Display the unique values and count of NaNs in the 'EmployeeName' column
print(df['EmployeeName'].unique())
print(df['EmployeeName'].isnull().sum())
# Out:
# ['albert pardini' 'john doe' 'jane smith']
# 0

# %% [markdown]
# ##### 7. Drop The Rows Having 5 Missing Values

# %%
df = pd.DataFrame(data)

# Count the number of missing values in each row
missing_counts = df.isna().sum(axis=1)

# Filter out rows with exactly 5 missing values
df_filtered = df[missing_counts != 5]

# Alternatively, to drop rows in place
# df.drop(df[missing_counts == 5].index, inplace=True)

print(df_filtered)
# Out:
#      A    B    C    D    E    F
# 0  1.0  NaN  NaN  1.0  NaN  1.0
# 1  NaN  2.0  NaN  2.0  NaN  NaN
# 2  3.0  NaN  3.0  NaN  NaN  3.0
# 3  NaN  4.0  NaN  NaN  4.0  NaN
# 4  5.0  NaN  5.0  NaN  NaN  NaN
# 5  NaN  6.0  NaN  NaN  6.0  NaN

# %% [markdown]
# ##### 8. Find The Job Title Of ALBERT PARDINI

# %%
df = pd.DataFrame(data)

# Locate the job title for 'ALBERT PARDINI'
job_title = df.loc[df['EmployeeName'] == 'ALBERT PARDINI', 'JobTitle'].values

if job_title.size > 0:
    print(f"Job Title of ALBERT PARDINI is" , job_title[0])
else:
    print("ALBERT PARDINI not found in the DataFrame.")
# Out:
# Job Title of ALBERT PARDINI is CAPTAIN III (POLICE DEPARTMENT)

# %% [markdown]
# ##### 9. How Much ALBERT PARDINI makes(include Benefits)

# %%
# Replace NaN values in the 'Benefits' column with 0.0
df['Benefits'].fillna(0.0, inplace=True)

# Filter the DataFrame for Albert Pardini
albert_pardini_data = df[df['EmployeeName'].str.upper() == 'ALBERT PARDINI']

# Check if data is found
if not albert_pardini_data.empty:
    # Extract relevant information
    job_title = albert_pardini_data['JobTitle'].values[0]
    base_pay = albert_pardini_data['BasePay'].values[0]
    overtime_pay = albert_pardini_data['OvertimePay'].values[0]
    other_pay = albert_pardini_data['OtherPay'].values[0]
    benefits = albert_pardini_data['Benefits'].values[0]
    total_pay = albert_pardini_data['TotalPay'].values[0]
    total_pay_benefits = albert_pardini_data['TotalPayBenefits'].values[0]
    # Display the information
    print(f"Employee Name: Albert Pardini")
    print(f"Job Title: {job_title}")
    print(f"Base Pay: ${base_pay:,.2f}")
    print(f"Overtime Pay: ${overtime_pay:,.2f}")
    print(f"Other Pay: ${other_pay:,.2f}")
    print(f"Benefits: ${benefits:,.2f}")
    print(f"Total Pay: ${total_pay:,.2f}")
    print(f"Total Pay & Benefits: ${total_pay_benefits:,.2f}")
else:
    print("Albert Pardini's data not found in the dataset.")
# Define labels and values
labels = ['Base Pay', 'Overtime Pay', 'Other Pay', 'Benefits']
values = [base_pay, overtime_pay, other_pay, benefits]

# Ensure values sum to more than 0 for visualization
if sum(values) > 0:
    plt.figure(figsize=(7, 7))
    plt.pie(values, labels=labels, autopct='%1.1f%%', colors=['skyblue', 'orange', 'green', 'red'], startangle=140)
    plt.title("Albert Pardini's Salary Breakdown")
    plt.show()
else:
    print("Salary components are all zero, skipping pie chart.")
# Out:
# Employee Name: Albert Pardini
# Job Title: CAPTAIN III (POLICE DEPARTMENT)
# Base Pay: $212,739.13
# Overtime Pay: $106,088.18
# Other Pay: $16,452.60
# Benefits: $0.00
# Total Pay: $335,279.91
# Total Pay & Benefits: $335,279.91

# %% [markdown]
# ##### 10. Display Name Of The Person Having The Highest Basepay

# %%
# Ensure 'BasePay' is numeric, coerce errors to NaN
df['BasePay'] = pd.to_numeric(df['BasePay'], errors='coerce')

# Drop rows where 'BasePay' is NaN
df = df.dropna(subset=['BasePay'])

# Sort the DataFrame by 'BasePay' in descending order and select the top 10 entries
top_10_basepay = df.nlargest(10, 'BasePay')

# Extract the employee names and their corresponding base pay
employee_names = top_10_basepay['EmployeeName']
base_pays = top_10_basepay['BasePay']

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.barh(employee_names, base_pays, color='skyblue')
plt.xlabel('Base Pay ($)')
plt.ylabel('Employee Name')
plt.title('Top 10 Employees with Highest Base Pay')
plt.gca().invert_yaxis()  # Invert y-axis to have the highest base pay at the top
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()

# Display the bar chart
plt.show()

# %% [markdown]
# ##### 11. Find The average Basepay of all Employees per Year

# %%
# Ensure 'Year' and 'BasePay' are correctly formatted
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')  # Convert to numeric
df['BasePay'] = pd.to_numeric(df['BasePay'], errors='coerce')  # Convert to float

# Group by 'Year' and calculate the average BasePay
avg_basepay_per_year = df.groupby('Year')['BasePay'].mean().dropna()  # Remove NaN values

# Display the results
print(avg_basepay_per_year)
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
# Plot a bar chart for Average BasePay per Year
plt.figure(figsize=(8, 5))
plt.bar(avg_basepay_per_year.index, avg_basepay_per_year.values, color='blue', alpha=0.7)

# Labeling
plt.xlabel("Year")
plt.ylabel("Average Base Pay ($)")
plt.title("Average BasePay of Employees Per Year")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the bar chart
plt.show()

# %%
# Line chart for better trend visualization
plt.figure(figsize=(8, 5))
plt.plot(avg_basepay_per_year.index, avg_basepay_per_year.values, marker='o', linestyle='-', color='blue')

# Labeling
plt.xlabel("Year")
plt.ylabel("Average Base Pay ($)")
plt.title("Average BasePay of Employees Per Year")
plt.xticks(rotation=45)
# Out:
# (array([2010.5, 2011. , 2011.5, 2012. , 2012.5, 2013. , 2013.5, 2014. ,
#         2014.5]),
#  [Text(2010.5, 0, '2010.5'),
#   Text(2011.0, 0, '2011.0'),
#   Text(2011.5, 0, '2011.5'),
#   Text(2012.0, 0, '2012.0'),
#   Text(2012.5, 0, '2012.5'),
#   Text(2013.0, 0, '2013.0'),
#   Text(2013.5, 0, '2013.5'),
#   Text(2014.0, 0, '2014.0'),
#   Text(2014.5, 0, '2014.5')])

# %% [markdown]
# ##### 12. Find Average Basepay Of All Employee Per Job Title

# %%
# Ensure 'BasePay' is numeric to avoid errors
df['BasePay'] = pd.to_numeric(df['BasePay'], errors='coerce')  # Convert to float

# Group by 'JobTitle' and calculate the average BasePay
avg_basepay_per_job = df.groupby('JobTitle')['BasePay'].mean().dropna().sort_values(ascending=False)

# Display the top job titles
print(avg_basepay_per_job.head(10))  # Show the top 10 highest-paid job titles
# Out:
# JobTitle
# Chief of Police                           309767.683333
# Chief, Fire Department                    304232.340000
# Gen Mgr, Public Trnsp Dept                297769.413333
# CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)    285262.000000
# Dep Dir for Investments, Ret              276153.765000
# Mayor                                     275852.530000
# Adm, SFGH Medical Center                  265218.780000
# EXECUTIVE CONTRACT EMPLOYEE               264452.520000
# Controller                                263588.753333
# Dept Head V                               259590.712222
# Name: BasePay, dtype: float64

# %%
# Select top 10 highest-paying job titles
top_10_jobs = avg_basepay_per_job.head(10)

# Plot a horizontal bar chart
plt.figure(figsize=(10, 6))
plt.barh(top_10_jobs.index, top_10_jobs.values, color='blue', alpha=0.7)

# Labeling
plt.xlabel("Average Base Pay ($)")
plt.ylabel("Job Title")
plt.title("Top 10 Job Titles with Highest Average BasePay")
plt.gca().invert_yaxis()  # Invert y-axis for better readability
plt.grid(axis='x', linestyle='--', alpha=0.7)

# Show the bar chart
plt.show()

# %% [markdown]
# ##### 13. Find The Average Basepay of All Employee Having job Title Accountant

# %%
# Load the dataset
df = pd.read_csv('Salaries.csv')

# Ensure 'BasePay' is numeric
df['BasePay'] = pd.to_numeric(df['BasePay'], errors='coerce')  # Convert to float

# Filter only rows where JobTitle is "Accountant"
accountants_df = df[df['JobTitle'].str.contains('Accountant', case=False, na=False)]

# Compute the average BasePay
avg_basepay_accountant = accountants_df['BasePay'].mean()

# Display the result
print(f"Average BasePay for Accountants: ${avg_basepay_accountant:,.2f}")
# Out:
# Average BasePay for Accountants: $72,245.57

# %% [markdown]
# ##### 14. Five most common job

# %%
# Count the occurrences of each JobTitle
job_counts = df['JobTitle'].value_counts().nlargest(5)  # Get top 5

# Display the results
print(job_counts)
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %%
# Plot a bar chart for the most common job titles
plt.figure(figsize=(8, 5))
plt.bar(job_counts.index, job_counts.values, color='green', alpha=0.7)

# Labeling
plt.xlabel("Job Title")
plt.ylabel("Number of Employees")
plt.title("Top 5 Most Common Job Titles")
plt.xticks(rotation=45, ha='right')  # Rotate for readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the bar chart
plt.show()

# %%
# Plot a pie chart for the most common job titles
plt.figure(figsize=(8, 5))
plt.pie(job_counts.values, labels=job_counts.index, autopct='%1.1f%%', colors=['blue', 'green', 'red', 'purple', 'orange'])

# Title
plt.title("Top 5 Most Common Job Titles")

# Show the pie chart
plt.show()
